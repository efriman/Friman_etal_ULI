# %%
# import standard python libraries
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 96
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from adjustText import adjust_text
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
os.chdir("/path/")

# %%
TFs = pd.read_csv("Mus_musculus_TF.txt", sep="\t")
TFs["Factor"] = TFs["Symbol"].str.upper()

# %%
Cofactor = pd.read_csv("Mus_musculus_TF_cofactors.txt", sep="\t")
Cofactor["Factor"] = Cofactor["Symbol"].str.upper()

# %%
RAD21_UT_short = pd.read_csv("Hsieh2021_RAD21-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
RAD21_UT_long = pd.read_csv("Hsieh2021_RAD21-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

RAD21_AID_short = pd.read_csv("Hsieh2021_RAD21-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
RAD21_AID_long = pd.read_csv("Hsieh2021_RAD21-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

WAPL_UT_short = pd.read_csv("Hsieh2021_WAPL-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
WAPL_UT_long = pd.read_csv("Hsieh2021_WAPL-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

WAPL_AID_short = pd.read_csv("Hsieh2021_WAPL-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
WAPL_AID_long = pd.read_csv("Hsieh2021_WAPL-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

CTCF_UT_short = pd.read_csv("Hsieh2021_CTCF-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
CTCF_UT_long = pd.read_csv("Hsieh2021_CTCF-UT_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

CTCF_AID_short = pd.read_csv("Hsieh2021_CTCF-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
CTCF_AID_long = pd.read_csv("Hsieh2021_CTCF-AID_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

RING1B_WT_short = pd.read_csv("Boyle_WT.mm10.mapq_30.1000_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
RING1B_WT_long = pd.read_csv("Boyle_WT.mm10.mapq_30.1000_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

RING1B_KO_short = pd.read_csv("Boyle_KO.mm10.mapq_30.1000_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_shortrange.txt", sep="\t")
RING1B_KO_long = pd.read_csv("Boyle_KO.mm10.mapq_30.1000_mm10-cCREs_ESC_DNase_merged5kb_mm10.bed_expected_noflank_10kbres_100kbto10Mb_stripe.clpy_mm10-cCREs_ESC_DNase_merged5kb_mm10_cistromeDB_ReMap2020_filtered.bed_longrange.txt", sep="\t")

# %%
combined = pd.DataFrame()
nameslist = ["RAD21", "CTCF", "WAPL", "RING1B"]
dflist = [[RAD21_UT_short, RAD21_UT_long, RAD21_AID_short, RAD21_AID_long],
         [CTCF_UT_short, CTCF_UT_long, CTCF_AID_short, CTCF_AID_long],
         [WAPL_UT_short, WAPL_UT_long, WAPL_AID_short, WAPL_AID_long],
         [RING1B_WT_short, RING1B_WT_long, RING1B_KO_short, RING1B_KO_long]]
for i in range(len(nameslist)):
    dflist[i][0]["Range"] = "short"
    dflist[i][1]["Range"] = "long"
    dflist[i][2]["Range"] = "short"
    dflist[i][3]["Range"] = "long"
    dflist[i][0]["Condition"] = "WT"
    dflist[i][1]["Condition"] = "WT"
    dflist[i][2]["Condition"] = "Treatment"
    dflist[i][3]["Condition"] = "Treatment"
    concat = pd.concat(dflist[i])
    concat["Degron"] = nameslist[i]
    combined = pd.concat([combined, concat], axis=0)
    
combined["Factor"] = combined.ID_Factor.str.split('_', n=1).str[1]

# %%
combined["F_mean"] = combined.groupby(["Range", "Condition", "Degron"])["F_value"].transform("mean")

# %%
combined["F_normalised"] = combined["F_value"] / combined["F_mean"]

# %%
#Rename factors (RBP1 misnamed in GEO)
combined["Factor"] = np.where(combined["Factor"] == "RNF2", "RING1B", combined["Factor"])
combined["Factor"] = np.where(combined["Factor"] == "CXXC1", "CFP1", combined["Factor"])
combined["Factor"] = np.where(combined["Factor"] == "POLR2A", "RPB1", combined["Factor"])
combined["Factor"] = np.where(combined["ID_Factor"] == "GSE137491_RBP1", "RPB1", combined["Factor"])

# %%
#Manual annotation of groups
TF = TFs["Factor"].tolist() + ["SMAD2/3", "SMAD2-3", 'ISL1-2']
Cofactors = Cofactor["Factor"].tolist() + ["ZNF143", "CFP1", "RPB1", "KMT2D", "CHD2", "SUPT5H"]
Cohesin = ['CTCF', 'SMC1A', 'RAD21', 'STAG1', 'STAG2', 'SMC3', 'WAPL', 'NIPBL']
Polycomb = ['PHC1', 'RING1B', 'RING1A', 'RING1B', 'EED', 'EZH2', 'CBX2', 'SUZ12', 
            'CBX7',  'RBP1', 'MTF2', 'PCGF2', 'RYBP', 'KDM2B', 'BAP1',
            'PCGF6', 'CBX6', 'PCGF1', 'PHF19', 'CBX8', 'JARID2', 'EPOP']
Repressive = ['CHD4', 'TRIM28', 'SINHCAF', 'TET1', 'TET3', 'SIN3A', 'DNMT3B', 
              'REST', 'HEXIM1', 'CBX1', 'CBX5', 'CBX3']

# %%
combined["Group"] = "Other"
combined.loc[combined["Factor"].isin(TF),"Group"] = "TF"
combined.loc[combined["Factor"].isin(Cofactors),"Group"] = "Co-factors"
combined.loc[combined["Factor"].isin(Repressive),"Group"] = "Repressive"
combined.loc[combined["Factor"].isin(Polycomb),"Group"] = "Polycomb"
combined.loc[combined["Factor"].isin(Cohesin),"Group"] = "Cohesin"

# %%
palette2 = {f:'whitesmoke' for f in set(combined["Group"])}
for f in combined.loc[combined["Group"] == "TF","Group"]:
    palette2[f] = '#4daf4a' 
for f in combined.loc[combined["Group"] == "Co-factors","Group"]:
    palette2[f] = '#e41a1c' 
for f in combined.loc[combined["Group"] == "Cohesin","Group"]:
    palette2[f] = 'orange'
for f in combined.loc[combined["Group"] == "Polycomb","Group"]:
    palette2[f] = '#377eb8'
for f in combined.loc[combined["Group"] == "Repressive","Group"]:
    palette2[f] = 'cyan'

# %%
pd.pivot(combined.loc[(combined["Range"]=="short") &
                             (combined["Degron"]=="RAD21"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
# Out:
# Condition           ID_Factor       Group  Treatment        WT
# 0            ENCSR000CCB_CTCF     Cohesin   0.909001  1.003843
# 1           ENCSR000CCD_EP300  Co-factors   0.961467  0.941716
# 2          ENCSR000ERV_ZFP384          TF   0.903716  0.928596
# 3          ENCSR000ERV_ZFP414          TF   0.917166  0.932125
# 4            ENCSR362VNF_CTCF     Cohesin   0.892862  0.999476
# ..                        ...         ...        ...       ...
# 468           GSE98988_POLR2A  Co-factors   0.986719  0.938759
# 469            GSE99022_KDM1A  Co-factors   0.895989  0.904406
# 470            GSE99022_KMT2B  Co-factors   0.976403  0.938834
# 471              GSE99518_YY1          TF   0.936481  0.922415
# 472             GSE99847_E2F1          TF   1.095779  1.032215
#
# [473 rows x 4 columns]

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="short") &
                             (combined["Degron"]=="RAD21"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='RAD21-AID short-range', 
      ylabel="Normalised F\n[AID/UT]", 
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/RAD21_shortrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/3941157633.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="long") &
                             (combined["Degron"]=="RAD21"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='RAD21-AID long-range', 
      ylabel="Normalised F\n[AID/UT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/RAD21_longrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/3768260093.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="short") &
                             (combined["Degron"]=="CTCF"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='CTCF-AID short-range', 
      ylabel="Normalised F\n[AID/UT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/CTCF_shortrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/170063239.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="long") &
                             (combined["Degron"]=="CTCF"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='CTCF-AID long-range', 
      ylabel="Normalised F\n[AID/UT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/CTCF_longrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/291354841.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="short") &
                             (combined["Degron"]=="WAPL"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='WAPL-AID short-range', 
      ylabel="Normalised F\n[AID/UT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/WAPL_shortrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/2006445204.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="long") &
                             (combined["Degron"]=="WAPL"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='WAPL-AID long-range', 
      ylabel="Normalised F\n[AID/UT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/WAPL_longrange_AID.svg")
# Out:
# /tmp/ipykernel_18023/393589428.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="short") &
                             (combined["Degron"]=="RING1B"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='Ring1b KO short-range', 
      ylabel="Normalised F\n[KO/WT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/RING1B_shortrange_KO.svg")
# Out:
# /tmp/ipykernel_18023/209589063.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,

# %%
cm = 1/2.54
sns.set(style="ticks", font="Arial")
sns.set_context("notebook", rc={"font.size":1,"axes.titlesize":12, 
                                "axes.labelsize":12, "xtick.labelsize": 10,
                                "ytick.labelsize": 10}) 
plt.figure(figsize=(8*cm,4.5*cm))
data = pd.pivot(combined.loc[(combined["Range"]=="long") &
                             (combined["Degron"]=="RING1B"),
                             ["ID_Factor", "F_normalised", "Condition", "Group"]], 
                index=["ID_Factor", "Group"], 
                columns="Condition", 
                values=["F_normalised"]).droplevel(0, axis=1).reset_index()
data["Treatment/WT"] = data["Treatment"] / data["WT"]
g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
                  edgecolor="black", linewidth=0.75, zorder=1, size=3,
                  order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
sns.boxplot(data=data, y="Treatment/WT", x = "Group", palette=palette2, 
            ax=g, linewidth=1, showfliers = False, 
            order=["Cohesin", "Polycomb", "Co-factors", "TF", "Repressive", "Other"])
g.set(title='Ring1b KO long-range', 
      ylabel="Normalised F\n[KO/WT]",
      xlabel = "",
      ylim=[0.8, 1.2])
plt.axhline(1,alpha=1, dashes=(1, 1), color="black")
plt.setp(g.artists, edgecolor = 'k')
plt.setp(g.lines, color='k')
sns.despine(trim=True, offset=0)
plt.tight_layout()
plt.xticks(rotation=30, ha="right")
plt.savefig("plots/RING1B_longrange_KO.svg")
# Out:
# /tmp/ipykernel_18023/3274144950.py:14: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.stripplot(data=data, y="Treatment/WT", x = "Group", palette=palette2,
